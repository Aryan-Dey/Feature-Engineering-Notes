# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler , OneHotEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv('E:\\Notes\\Statistics\\Feature Engineering\\Datasets\\train.csv', usecols=['Survived', 'Pclass',	'Sex',	'Age',	'SibSp', 'Parch',	'Fare',	'Embarked'])
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
X = df.drop(columns=['Survived'])
y = df['Survived']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
X_train.head()
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 30        1    male  40.0      0      0  27.7208        C
# 10        3  female   4.0      1      1  16.7000        S
# 873       3    male  47.0      0      0   9.0000        S
# 182       3    male   9.0      4      2  31.3875        S
# 876       3    male  20.0      0      0   9.8458        S

# %% [markdown]
# **Defining Preprocessing Pipeline**

# %%
numerical_features = ['Age','Fare']
numerical_trf = Pipeline(steps = [
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categorical_features = ['Embarked','Sex']
categorical_trf = Pipeline(steps = [
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ohe', OneHotEncoder(handle_unknown='ignore'))
])

# %% [markdown]
# **Combining Preprocessing Steps**

# %%
preprocessor = ColumnTransformer([
    ('num', numerical_trf, numerical_features),
    ('cat', categorical_trf, categorical_features)
])

# %% [markdown]
# **Creating Final Pipeline**

# %%
clf = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', LogisticRegression())
])

# %%
clf
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Age', 'Fare']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
# ...

# %%
# clf.get_params().keys()

# %%
# print(type(X_train))
# print(type(y_train))

# %%
# X_train = X_train.values.ravel()
# y_train = y_train.values.ravel()

# %%
# print(type(X_train))
# print(type(y_train))

# %% [markdown]
# **Defining Hyperparameter Grid**

# %%
param_grid= {
    'preprocessor__num_imputer_strategy': ['mean','median'],
    'preprocessor__cat_imputer_strategy': ['most_frequent', 'constant'],
    'classifier__C': [0.1, 1.0, 10, 100]
}

grid_search = GridSearchCV(clf, param_grid, cv=10)

# %%
grid_search.fit(X_train, y_train)
print('Best Parameters:', grid_search.best_params_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 grid_search.fit(X_train, y_train)
#       2 print('Best Parameters:', grid_search.best_params_)
#
# File c:\Users\Aryan\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Aryan\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:1024, in BaseSearchCV.fit(self, X, y, **params)
#    1018     results = self._format_results(
# ...

# %%
print(f'Internal CV Score: {grid_search.best_score_: .3f}')
# This will give the maximum algorithm score for the best parameters
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(f'Internal CV Score: {grid_search.best_score_: .3f}')
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_score_'
